# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A53057/DAV/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(df['Product Category'], df['Units Sold'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Units Sold')
plt.title('Total Units Sold by Product Category (Matplotlib)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

data = {'Product Category': ['Electronics', 'Clothing', 'Home Appliances', 'Groceries'],
        'Units Sold': [1500, 2200, 800, 3000]}
df = pd.DataFrame(data)

# %%
import pandas as pd

data = {'Product Category': ['Electronics', 'Clothing', 'Home Appliances', 'Groceries'],
        'Units Sold': [1500, 2200, 800, 3000]}
df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

category=["Electronics","Clothing","Home appliances","groceries"]
units=[350,220,150,500]
plt.figure(figsize=(10, 6))
plt.bar(df['Product Category'], df['Units Sold'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Units Sold')
plt.title('Total Units Sold by Product Category (Matplotlib)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

category=["Electronics","Clothing","Home appliances","groceries"]
units=[350,220,150,500]
plt.figure(figsize=(10, 6))
plt.bar(df['Product Category'], df['Units Sold'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Units Sold')
plt.title('Total Units Sold by Product Category (Matplotlib)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
